# %% [markdown]
# ### Human in the Loop Concept

# %% [markdown]
# Implementing human in the loop  inculde few steps
# -   Stop the halt the workflow when human in the loop is required and save the state using the persistance
# -   Take the input from the human
# -   Resume the workflow using the save state implementing the concept of the persistance
